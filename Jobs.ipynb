# %%
#pip install python-jobspy

# %%
import pandas as pd
import csv
from jobspy import scrape_jobs

# Define multiple search terms
search_terms = ["data Analyst", "data scientist", "postdoc", "Scientist"]

# Initialize an empty DataFrame to store all jobs
all_jobs = pd.DataFrame()

# Iterate over each search term and aggregate the results
for term in search_terms:
    jobs = scrape_jobs(
        site_name=["indeed", "linkedin", "glassdoor"],
        search_term=term,
        location="Berlin",
        results_wanted=100,
        hours_old=72,
        country_indeed='Germany'
    )
    # Check jobs df, if it's not empty before concatenating
    if not jobs.empty:
        all_jobs = pd.concat([all_jobs, jobs], ignore_index=True)

# Display the number of jobs found
print(f"Found {len(all_jobs)} jobs")

all_jobs.head()
# Out:
# 2024-02-26 13:10:03,471 - JobSpy - ERROR - ZipRecruiter response status code 403
# /Users/amr/anaconda3/lib/python3.11/site-packages/jobspy/__init__.py:155: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   jobs_df = pd.concat(jobs_dfs, ignore_index=True)
# 2024-02-26 13:10:27,128 - JobSpy - ERROR - ZipRecruiter response status code 403
# /Users/amr/anaconda3/lib/python3.11/site-packages/jobspy/__init__.py:155: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   jobs_df = pd.concat(jobs_dfs, ignore_index=True)
# 2024-02-26 13:10:46,696 - JobSpy - ERROR - ZipRecruiter response status code 403
# /var/folders/q2/_chm3qg94gz5l7r736h39n040000gn/T/ipykernel_16597/480919763.py:23: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   all_jobs = pd.concat([all_jobs, jobs], ignore_index=True)
# 2024-02-26 13:10:51,063 - JobSpy - ERROR - 429 Response - Blocked by Glassdoor for too many requests
# 2024-02-26 13:10:51,299 - JobSpy - ERROR - ZipRecruiter response status code 403
# Found 266 jobs
# /Users/amr/anaconda3/lib/python3.11/site-packages/jobspy/__init__.py:155: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   jobs_df = pd.concat(jobs_dfs, ignore_index=True)
#                                              job_url       site  \
# 0  https://www.glassdoor.de/job-listing/j?jl=1009...  glassdoor
# 1  https://www.glassdoor.de/job-listing/j?jl=1009...  glassdoor
# 2  https://www.glassdoor.de/job-listing/j?jl=1009...  glassdoor
# 3  https://www.glassdoor.de/job-listing/j?jl=1009...  glassdoor
# 4  https://www.glassdoor.de/job-listing/j?jl=1009...  glassdoor
#
#                                                title  \
# 0                            Data Analyst*in (d/m/w)
# 1  Duales Studium – Bachelor of Science Informati...
# 2                          Marketing Analyst (m/f/d)
# 3                  Social Media Data Analyst (w/m/d)
# 4         (Senior) Expert Investor Relations (m/w/d)
#
#                                   company  \
# 0                       Toll Collect GmbH
# 1  Kassenärztliche Bundesvereinigung KdöR
# 2                              aeydē GmbH
# 3                                    TLGG
# 4                               KWS Group
#
#                                          company_url location job_type  \
# 0  https://www.glassdoor.de/Overview/W-EI_IE79556...   Berlin     None
# 1  https://www.glassdoor.de/Overview/W-EI_IE68192...   Berlin     None
# 2  https://www.glassdoor.de/Overview/W-EI_IE30208...   Berlin     None
# 3  https://www.glassdoor.de/Overview/W-EI_IE87290...   Berlin     None
# 4  https://www.glassdoor.de/Overview/W-EI_IE93422...   Berlin     None
#
#   date_posted interval  min_amount  max_amount currency is_remote  \
# 0  2024-02-26     None         NaN         NaN     None     False
# 1  2024-02-26     None         NaN         NaN     None     False
# 2  2024-02-25     None         NaN         NaN     None     False
# 3  2024-02-25     None         NaN         NaN     None     False
# 4  2024-02-24     None         NaN         NaN     None     False
#
#   num_urgent_words benefits                    emails  \
# 0                0     None  karriere@toll-collect.de
# 1                0     None                      None
# 2                0     None                      None
# 3                0     None                      None
# 4                0     None                      None
#
#                                          description
# 0  Referenznummer: 20643\n\nIhre Aufgaben\n\n    ...
# 1  Mehr als 100.000 Praxen arbeiten mit der IT, d...
# 2  Your tasks  \n  \nAcquisition Strategy (50%)  ...
# 3  Daten über das Social Media Verhalten deiner Z...
# 4  r dich keine Herausforderungen dar und Kennzah...

# %%
# Remove duplicate entries based on 'company' and 'title' columns
all_jobs.drop_duplicates(subset=['date_posted', 'company', 'title'], inplace=True, ignore_index=True)

# Display the number of jobs found after removing duplicates
print(f"Found {len(all_jobs)} jobs after removing duplicates")

all_jobs.sort_values(by='date_posted', ascending=False, inplace=True)

# Display the top 5 rows of the all_jobs DataFrame
all_jobs
# Out:
# Found 206 jobs after removing duplicates
#                                                job_url       site  \
# 0    https://www.glassdoor.de/job-listing/j?jl=1009...  glassdoor
# 11   https://de.indeed.com/viewjob?jk=7f470b4e4b72c6bd     indeed
# 126  https://de.indeed.com/viewjob?jk=66381d827d21e93f     indeed
# 1    https://www.glassdoor.de/job-listing/j?jl=1009...  glassdoor
# 12   https://de.indeed.com/viewjob?jk=813a90e67be0271c     indeed
# ..                                                 ...        ...
# 201      https://www.linkedin.com/jobs/view/3834849654   linkedin
# 202      https://www.linkedin.com/jobs/view/3727087476   linkedin
# 203      https://www.linkedin.com/jobs/view/3733045332   linkedin
# 204      https://www.linkedin.com/jobs/view/3834701559   linkedin
# 205      https://www.linkedin.com/jobs/view/3834859823   linkedin
#
#                                                  title  \
# 0                              Data Analyst*in (d/m/w)
# 11                                     Data Specialist
# 126                                     Data Scientist
# 1    Duales Studium – Bachelor of Science Informati...
# 12                 Duales Studium Zum Bachelor of Arts
# ..                                                 ...
# 201  Senior Scientist for a Permanent Position in A...
# 202  Data Science Manager (Bangkok based, relocatio...
# 203  (Senior) Consultant Data & Analytics - Projekt...
# 204  Senior Data Scientist, Totogi (Remote) - $400,...
# 205  Startup Founder (May 2024) - Software Engineer...
#
#                                     company  \
# 0                         Toll Collect GmbH
# 11                        Toll Collect GmbH
# 126                       Toll Collect GmbH
# 1    Kassenärztliche Bundesvereinigung KdöR
# 12   Kassenärztliche Bundesvereinigung KdöR
# ..                                      ...
# 201                                    DESY
# 202                                   Agoda
# 203                               adesso SE
# 204                               Crossover
# 205                                  Antler
#
#                                            company_url  \
# 0    https://www.glassdoor.de/Overview/W-EI_IE79556...
# 11         https://de.indeed.com/cmp/Toll-Collect-Gmbh
# 126        https://de.indeed.com/cmp/Toll-Collect-Gmbh
# 1    https://www.glassdoor.de/Overview/W-EI_IE68192...
# 12   https://de.indeed.com/cmp/Kassen%C3%A4rztliche...
# ..                                                 ...
# 201               https://de.linkedin.com/company/desy
# 202              https://sg.linkedin.com/company/agoda
# 203          https://de.linkedin.com/company/adesso-se
# 204         https://www.linkedin.com/company/crossover
# 205       https://sg.linkedin.com/company/antlerglobal
#
#                           location  job_type date_posted interval  min_amount  \
# 0                           Berlin      None  2024-02-26     None         NaN
# 11             Berlin, BE, Germany      None  2024-02-26     None         NaN
# 126            Berlin, BE, Germany      None  2024-02-26     None         NaN
# 1                           Berlin      None  2024-02-26     None         NaN
# 12             Berlin, BE, Germany  fulltime  2024-02-26     None         NaN
# ..                             ...       ...         ...      ...         ...
# 201  Zeuthen, Brandenburg, Germany      None        None     None         NaN
# 202        Berlin, Berlin, Germany      None        None     None         NaN
# 203        Berlin, Berlin, Germany      None        None     None         NaN
# 204        Berlin, Berlin, Germany      None        None     None       200.0
# 205                Berlin, Germany      None        None     None         NaN
#
#      max_amount currency is_remote num_urgent_words               benefits  \
# 0           NaN     None     False                0                   None
# 11          NaN     None      True                0                   None
# 126         NaN     None      True                0                   None
# 1           NaN     None     False                0                   None
# 12          NaN     None     False                0                   None
# ..          ...      ...       ...              ...                    ...
# 201         NaN     None      None             None  Be an early applicant
# 202         NaN     None      None             None        Actively Hiring
# 203         NaN     None      None             None        Actively Hiring
# 204       200.0      USD      None             None  Be an early applicant
# 205         NaN     None      None             None  Be an early applicant
#
#                        emails  \
# 0    karriere@toll-collect.de
# 11   karriere@toll-collect.de
# 126  karriere@toll-collect.de
# 1                        None
# 12                       None
# ..                        ...
# 201                      None
# 202                      None
# 203                      None
# 204                      None
# 205                      None
#
#                                            description
# 0    Referenznummer: 20643\n\nIhre Aufgaben\n\n    ...
# 11   Referenznummer: 20643\n\nIhre Aufgaben\n\n    ...
# 126  Referenznummer: 20622\n\nIhre Aufgaben  \n\n  ...
# 1    Mehr als 100.000 Praxen arbeiten mit der IT, d...
# 12   Mehr als 100.000 Praxen arbeiten mit der IT, d...
# ..                                                 ...
# 201                                               None
# 202                                               None
# 203                                               None
# 204                                               None
# 205                                               None
#
# [206 rows x 17 columns]

# %%
all_jobs = all_jobs[['date_posted','title','company','site','job_url','description']]
all_jobs
# Out:
#     date_posted                                              title  \
# 0    2024-02-26                            Data Analyst*in (d/m/w)
# 11   2024-02-26                                    Data Specialist
# 126  2024-02-26                                     Data Scientist
# 1    2024-02-26  Duales Studium – Bachelor of Science Informati...
# 12   2024-02-26                Duales Studium Zum Bachelor of Arts
# ..          ...                                                ...
# 201        None  Senior Scientist for a Permanent Position in A...
# 202        None  Data Science Manager (Bangkok based, relocatio...
# 203        None  (Senior) Consultant Data & Analytics - Projekt...
# 204        None  Senior Data Scientist, Totogi (Remote) - $400,...
# 205        None  Startup Founder (May 2024) - Software Engineer...
#
#                                     company       site  \
# 0                         Toll Collect GmbH  glassdoor
# 11                        Toll Collect GmbH     indeed
# 126                       Toll Collect GmbH     indeed
# 1    Kassenärztliche Bundesvereinigung KdöR  glassdoor
# 12   Kassenärztliche Bundesvereinigung KdöR     indeed
# ..                                      ...        ...
# 201                                    DESY   linkedin
# 202                                   Agoda   linkedin
# 203                               adesso SE   linkedin
# 204                               Crossover   linkedin
# 205                                  Antler   linkedin
#
#                                                job_url  \
# 0    https://www.glassdoor.de/job-listing/j?jl=1009...
# 11   https://de.indeed.com/viewjob?jk=7f470b4e4b72c6bd
# 126  https://de.indeed.com/viewjob?jk=66381d827d21e93f
# 1    https://www.glassdoor.de/job-listing/j?jl=1009...
# 12   https://de.indeed.com/viewjob?jk=813a90e67be0271c
# ..                                                 ...
# 201      https://www.linkedin.com/jobs/view/3834849654
# 202      https://www.linkedin.com/jobs/view/3727087476
# 203      https://www.linkedin.com/jobs/view/3733045332
# 204      https://www.linkedin.com/jobs/view/3834701559
# 205      https://www.linkedin.com/jobs/view/3834859823
#
#                                            description
# 0    Referenznummer: 20643\n\nIhre Aufgaben\n\n    ...
# 11   Referenznummer: 20643\n\nIhre Aufgaben\n\n    ...
# 126  Referenznummer: 20622\n\nIhre Aufgaben  \n\n  ...
# 1    Mehr als 100.000 Praxen arbeiten mit der IT, d...
# 12   Mehr als 100.000 Praxen arbeiten mit der IT, d...
# ..                                                 ...
# 201                                               None
# 202                                               None
# 203                                               None
# 204                                               None
# 205                                               None
#
# [206 rows x 6 columns]

# %%
# Exclude jobs using certain keywords in the Title
keywords_to_exclude = ['Developer', 'Engineer', 'Software', 'Entwickler', 'Business', 'DevOps','Intern', 'Marketing','Finance', 'Senior Data']

# Create a mask that is True for rows to exclude
mask = pd.Series([False] * len(all_jobs))  # Initialize a mask to keep all rows
for keyword in keywords_to_exclude:
    mask = mask | all_jobs['title'].str.contains(keyword, case=False, na=False)

# Use the negation of the mask to filter the DataFrame
filtered_jobs = all_jobs[~mask]

filtered_jobs
# Out:
# /var/folders/q2/_chm3qg94gz5l7r736h39n040000gn/T/ipykernel_16597/3762788471.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_jobs = all_jobs[~mask]
#     date_posted                                              title  \
# 0    2024-02-26                            Data Analyst*in (d/m/w)
# 11   2024-02-26                                    Data Specialist
# 126  2024-02-26                                     Data Scientist
# 1    2024-02-26  Duales Studium – Bachelor of Science Informati...
# 12   2024-02-26                Duales Studium Zum Bachelor of Arts
# 121  2024-02-26  Data Scientist*in Einnahmesicherung und Auskeh...
# 197  2024-02-25  Fachinformatiker/in systemintegration, netzwer...
# 3    2024-02-25                  Social Media Data Analyst (w/m/d)
# 32   2024-02-25                             Data Scientist (w/m/d)
# 132  2024-02-25              (Senior) Data Scientist (all genders)
# 31   2024-02-25  (Senior) Consultant Customer Intelligence (all...
# 27   2024-02-25   Data Scientist Schwerpunkt Energiewende (m/w/d)*
# 193  2024-02-25  Wissenschafltiche r Mitarbeiter in (PostDoc) (...
# 122  2024-02-24                   Data Scientist - Pricing (w/m/d)
# 123  2024-02-24                                     Data Scientist
# 124  2024-02-24                       Scientist 6G Standardization
# 194  2024-02-24  Wissenschafltiche*r Mitarbeiter*in (PostDoc) (...
# 196  2024-02-24                                   Junior Scientist
# 190  2024-02-24                        Postdoc (m/f/d) HIPOLE Jena
# 198  2024-02-24  Volunteer: Whale Shark Conservation Project in...
# 200  2024-02-24  Volunteer: Shark Research, Education + Conserv...
# 13   2024-02-24                                    Data Specialist
# 8    2024-02-24              Senior Product Designer (all genders)
# 37   2024-02-24                               Data Analyst (m/w/d)
# 4    2024-02-24         (Senior) Expert Investor Relations (m/w/d)
# 5    2024-02-24                          Senior BI Analyst (f/m/x)
# 154  2024-02-23                           Principal Data Scientist
# 195  2024-02-23  Postdoctoral Fellow in Biochemistry or Structu...
# 192  2024-02-23                               Post-doctoral Fellow
# 191  2024-02-23                        Postdoc (m/f/d) Hipole Jena
# 169  2024-02-23             Informatiker/in in Berlin, Deutschland
# 21   2024-02-23                            Senior Product Designer
# 20   2024-02-23                             Senior Guest Relations
# 70   2024-02-23                   Data Scientist - Pricing (w/m/d)
# 63   2024-02-23  Werkstudent*in Python-Entwicklung für optische...
# 49   2024-02-23          Financial Data Analyst (d/f/m) at Solaris
# 130  2024-02-23                                     Data Scientist
# 129  2024-02-23                                     Data Scientist
# 128  2024-02-23                                          Scientist
# 127  2024-02-23                                     Data Scientist
# 85         None                 Digital Data Analyst (Entry Level)
# 87         None  Expert Data Analyst and Energy Market Modeler ...
# 88         None  Consultant Forensic Data Analytics (m/w/d) in ...
# 89         None  Data Analyst (Supply Analytics team, Bangkok-b...
# 94         None  (Senior) Consultant Visual Analytics & BI (m/w/d)
# 102        None                (Senior) Fraud Risk Analyst (m/f/d)
# 103        None                (Senior) Fraud Risk Analyst (m/w/d)
# 112        None                             Data Scientist (w/m/d)
# 116        None  Quality Assurance Analyst with German and English
# 177        None              (Senior) Data Scientist (all genders)
# 201        None  Senior Scientist for a Permanent Position in A...
# 202        None  Data Science Manager (Bangkok based, relocatio...
# 203        None  (Senior) Consultant Data & Analytics - Projekt...
#
#                                                company       site  \
# 0                                    Toll Collect GmbH  glassdoor
# 11                                   Toll Collect GmbH     indeed
# 126                                  Toll Collect GmbH     indeed
# 1               Kassenärztliche Bundesvereinigung KdöR  glassdoor
# 12              Kassenärztliche Bundesvereinigung KdöR     indeed
# 121                                  Toll Collect GmbH  glassdoor
# 197                                     Energy Jobline   linkedin
# 3                                                 TLGG  glassdoor
# 32                                             Siemens   linkedin
# 132                                          adesso SE   linkedin
# 31                                           adesso SE   linkedin
# 27                                          Tagueri AG   linkedin
# 193                                     Energy Jobline   linkedin
# 122                                               KPMG  glassdoor
# 123                                            Amadeus  glassdoor
# 124       Telecommunications, Heinrich Hertz Institute  glassdoor
# 194                      Technische Universität Berlin   linkedin
# 196                                         Kineo GmbH     indeed
# 190                                    Springer Nature  glassdoor
# 198                                     Global Nomadic   linkedin
# 200                                     Global Nomadic   linkedin
# 13                                                TLGG     indeed
# 8                                      craftdrive GmbH  glassdoor
# 37                                        Michael Page   linkedin
# 4                                            KWS Group  glassdoor
# 5                                            CarOnSale  glassdoor
# 154                        BMG - The New Music Company   linkedin
# 195  Leibniz-Forschungsinstitut für Molekulare Phar...   linkedin
# 192  Leibniz-Forschungsinstitut für Molekulare Phar...     indeed
# 191                                    Springer Nature     indeed
# 169                                     Energy Jobline   linkedin
# 21                                     craftdrive GmbH     indeed
# 20                                           KWS Group     indeed
# 70                                    KPMG Deutschland   linkedin
# 63             Fraunhofer Heinrich Hertz Institute HHI   linkedin
# 49                                          Solaris SE   linkedin
# 130        Bundesministerium für Digitales und Verkehr     indeed
# 129                                               KPMG     indeed
# 128       Telecommunications, Heinrich Hertz Institute     indeed
# 127                                            Amadeus     indeed
# 85                                  Hal Kompi Concepta   linkedin
# 87                                            Q ENERGY   linkedin
# 88                                            Deloitte   linkedin
# 89                                               Agoda   linkedin
# 94                                            Deloitte   linkedin
# 102                                            Riverty   linkedin
# 103                                            Riverty   linkedin
# 112                                            Siemens   linkedin
# 116                                           Conectys   linkedin
# 177                                          adesso SE   linkedin
# 201                                               DESY   linkedin
# 202                                              Agoda   linkedin
# 203                                          adesso SE   linkedin
#
#                                                job_url  \
# 0    https://www.glassdoor.de/job-listing/j?jl=1009...
# 11   https://de.indeed.com/viewjob?jk=7f470b4e4b72c6bd
# 126  https://de.indeed.com/viewjob?jk=66381d827d21e93f
# 1    https://www.glassdoor.de/job-listing/j?jl=1009...
# 12   https://de.indeed.com/viewjob?jk=813a90e67be0271c
# 121  https://www.glassdoor.de/job-listing/j?jl=1009...
# 197      https://www.linkedin.com/jobs/view/3837971742
# 3    https://www.glassdoor.de/job-listing/j?jl=1009...
# 32       https://www.linkedin.com/jobs/view/3816898375
# 132      https://www.linkedin.com/jobs/view/3733044085
# 31       https://www.linkedin.com/jobs/view/3733740894
# 27       https://www.linkedin.com/jobs/view/3837980042
# 193      https://www.linkedin.com/jobs/view/3837978129
# 122  https://www.glassdoor.de/job-listing/j?jl=1009...
# 123  https://www.glassdoor.de/job-listing/j?jl=1009...
# 124  https://www.glassdoor.de/job-listing/j?jl=1009...
# 194      https://www.linkedin.com/jobs/view/3839153353
# 196  https://de.indeed.com/viewjob?jk=196d283cfa89694e
# 190  https://www.glassdoor.de/job-listing/j?jl=1009...
# 198      https://www.linkedin.com/jobs/view/3803759864
# 200      https://www.linkedin.com/jobs/view/3803760860
# 13   https://de.indeed.com/viewjob?jk=fc9806aebb59a606
# 8    https://www.glassdoor.de/job-listing/j?jl=1009...
# 37       https://www.linkedin.com/jobs/view/3837708017
# 4    https://www.glassdoor.de/job-listing/j?jl=1009...
# 5    https://www.glassdoor.de/job-listing/j?jl=1009...
# 154      https://www.linkedin.com/jobs/view/3837028745
# 195      https://www.linkedin.com/jobs/view/3836891227
# 192  https://de.indeed.com/viewjob?jk=a498ca655f6db570
# 191  https://de.indeed.com/viewjob?jk=4e0379d09f9a06eb
# 169      https://www.linkedin.com/jobs/view/3837012033
# 21   https://de.indeed.com/viewjob?jk=7d5883f79a5bfdf8
# 20   https://de.indeed.com/viewjob?jk=efc3d19a515c2374
# 70       https://www.linkedin.com/jobs/view/3833819334
# 63       https://www.linkedin.com/jobs/view/3838716491
# 49       https://www.linkedin.com/jobs/view/3838453395
# 130  https://de.indeed.com/viewjob?jk=24be6e205949be82
# 129  https://de.indeed.com/viewjob?jk=bdc8c5633c3389ce
# 128  https://de.indeed.com/viewjob?jk=0ee2538f2613a9e0
# 127  https://de.indeed.com/viewjob?jk=185196c76dd1c1c4
# 85       https://www.linkedin.com/jobs/view/3834856103
# 87       https://www.linkedin.com/jobs/view/3840209315
# 88       https://www.linkedin.com/jobs/view/3549653207
# 89       https://www.linkedin.com/jobs/view/3838606564
# 94       https://www.linkedin.com/jobs/view/3630914774
# 102      https://www.linkedin.com/jobs/view/3774177265
# 103      https://www.linkedin.com/jobs/view/3784875658
# 112      https://www.linkedin.com/jobs/view/3817200150
# 116      https://www.linkedin.com/jobs/view/3840210822
# 177      https://www.linkedin.com/jobs/view/3733042224
# 201      https://www.linkedin.com/jobs/view/3834849654
# 202      https://www.linkedin.com/jobs/view/3727087476
# 203      https://www.linkedin.com/jobs/view/3733045332
#
#                                            description
# 0    Referenznummer: 20643\n\nIhre Aufgaben\n\n    ...
# 11   Referenznummer: 20643\n\nIhre Aufgaben\n\n    ...
# 126  Referenznummer: 20622\n\nIhre Aufgaben  \n\n  ...
# 1    Mehr als 100.000 Praxen arbeiten mit der IT, d...
# 12   Mehr als 100.000 Praxen arbeiten mit der IT, d...
# 121  Referenznummer: 20622\n\nIhre Aufgaben  \n\n  ...
# 197                                               None
# 3    Daten über das Social Media Verhalten deiner Z...
# 32                                                None
# 132                                               None
# 31                                                None
# 27                                                None
# 193                                               None
# 122  **Data Scientist - Pricing (w/m/d)**  \nJob-Nr...
# 123  **Job Title**\n\nData Scientist\n\n **Diversit...
# 124  The Fraunhofer-Gesellschaft (www.fraunhofer.co...
# 194                                               None
# 196  We are Kineo, a Berlin-based tech startup deve...
# 190  #  **Postdoc (m/f/d) HIPOLE Jena**\n\nEmployer...
# 198                                               None
# 200                                               None
# 13   Daten über das Social Media Verhalten deiner Z...
# 8    ####  **Why join us?**\n\nAt **koppla** we wan...
# 37                                                None
# 4    r dich keine Herausforderungen dar und Kennzah...
# 5    **CarOnSale** is a start-up in the heart of Be...
# 154                                               None
# 195                                               None
# 192  **Postdoctoral Fellow in Biochemistry or Struc...
# 191  #  **Postdoc (m/f/d) HIPOLE Jena**\n\nEmployer...
# 169                                               None
# 21
# 20
# 70                                                None
# 63                                                None
# 49                                                None
# 130  Das Bundesministerium fur Digitales und Verkeh...
# 129  **Data Scientist - Pricing (w/m/d)**  \nJob-Nr...
# 128  The Fraunhofer-Gesellschaft (www.fraunhofer.co...
# 127  **Job Title**\n\nData Scientist\n\n **Diversit...
# 85                                                None
# 87                                                None
# 88                                                None
# 89                                                None
# 94                                                None
# 102                                               None
# 103                                               None
# 112                                               None
# 116                                               None
# 177                                               None
# 201                                               None
# 202                                               None
# 203                                               None

# %%
# Path to existing Excel file
existing_file_path = 'jobs.xlsx'

# Read the existing Excel file into a DataFrame
existing_jobs = pd.read_excel(existing_file_path)

# Combine existing jobs with new filtered jobs into a df
combined_jobs = pd.concat([existing_jobs, filtered_jobs], ignore_index=True)

# Remove duplicates based on certain columns that uniquely identify a job listing
unique_jobs = combined_jobs.drop_duplicates(subset=['company', 'title', 'date_posted'], keep='first')

unique_jobs.to_excel(existing_file_path, index=False)
